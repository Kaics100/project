# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Yutube trending data/archive/USvideos.csv')
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
with open('Yutube trending data/archive/US_category_id.json') as f:
    json_data = json.load(f)

# %%
items = json_data['items']
item_dicts = []
for item in items:
    item_dict = {
        'id': item['id'],
        'category_title': item['snippet']['title']
    }
    item_dicts.append(item_dict)

# %%
item_dicts
# Out:
# [{'id': '1', 'category_title': 'Film & Animation'},
#  {'id': '2', 'category_title': 'Autos & Vehicles'},
#  {'id': '10', 'category_title': 'Music'},
#  {'id': '15', 'category_title': 'Pets & Animals'},
#  {'id': '17', 'category_title': 'Sports'},
#  {'id': '18', 'category_title': 'Short Movies'},
#  {'id': '19', 'category_title': 'Travel & Events'},
#  {'id': '20', 'category_title': 'Gaming'},
#  {'id': '21', 'category_title': 'Videoblogging'},
#  {'id': '22', 'category_title': 'People & Blogs'},
#  {'id': '23', 'category_title': 'Comedy'},
#  {'id': '24', 'category_title': 'Entertainment'},
#  {'id': '25', 'category_title': 'News & Politics'},
#  {'id': '26', 'category_title': 'Howto & Style'},
#  {'id': '27', 'category_title': 'Education'},
#  {'id': '28', 'category_title': 'Science & Technology'},
#  {'id': '29', 'category_title': 'Nonprofits & Activism'},
#  {'id': '30', 'category_title': 'Movies'},
#  {'id': '31', 'category_title': 'Anime/Animation'},
#  {'id': '32', 'category_title': 'Action/Adventure'},
#  {'id': '33', 'category_title': 'Classics'},
#  {'id': '34', 'category_title': 'Comedy'},
#  {'id': '35', 'category_title': 'Documentary'},
#  {'id': '36', 'category_title': 'Drama'},
#  {'id': '37', 'category_title': 'Family'},
#  {'id': '38', 'category_title': 'Foreign'},
#  {'id': '39', 'category_title': 'Horror'},
#  {'id': '40', 'category_title': 'Sci-Fi/Fantasy'},
#  {'id': '41', 'category_title': 'Thriller'},
#  {'id': '42', 'category_title': 'Shorts'},
#  {'id': '43', 'category_title': 'Shows'},
#  {'id': '44', 'category_title': 'Trailers'}]

# %%
id_to_title_df = pd.DataFrame(item_dicts)
id_to_title_df['id'] = id_to_title_df['id'].astype('int64')

# %%
id_to_title_df
# Out:
#     id         category_title
# 0    1       Film & Animation
# 1    2       Autos & Vehicles
# 2   10                  Music
# 3   15         Pets & Animals
# 4   17                 Sports
# 5   18           Short Movies
# 6   19        Travel & Events
# 7   20                 Gaming
# 8   21          Videoblogging
# 9   22         People & Blogs
# 10  23                 Comedy
# 11  24          Entertainment
# 12  25        News & Politics
# 13  26          Howto & Style
# 14  27              Education
# 15  28   Science & Technology
# 16  29  Nonprofits & Activism
# 17  30                 Movies
# 18  31        Anime/Animation
# 19  32       Action/Adventure
# 20  33               Classics
# 21  34                 Comedy
# 22  35            Documentary
# 23  36                  Drama
# 24  37                 Family
# 25  38                Foreign
# 26  39                 Horror
# 27  40         Sci-Fi/Fantasy
# 28  41               Thriller
# 29  42                 Shorts
# 30  43                  Shows
# 31  44               Trailers

# %%
merged_df = pd.merge(df, id_to_title_df, left_on='category_id', right_on='id', how='left')
merged_df.drop(columns=['id'], inplace=True)
category_id_index = merged_df.columns.get_loc('category_id')
merged_df.insert(category_id_index + 1, 'category_title', merged_df.pop('category_title'))

# %%
merged_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id    category_title  \
# 0                  CaseyNeistat           22    People & Blogs
# 1               LastWeekTonight           24     Entertainment
# 2                  Rudy Mancuso           23            Comedy
# 3         Good Mythical Morning           24     Entertainment
# 4                      nigahiga           24     Entertainment
# ...                         ...          ...               ...
# 40944             AaronsAnimals           15    Pets & Animals
# 40945                  zefrank1           22    People & Blogs
# 40946                Brad Mondo           24     Entertainment
# 40947  How It Should Have Ended            1  Film & Animation
# 40948              Call of Duty           20            Gaming
#
#                    publish_time  \
# 0      2017-11-13T17:13:01.000Z
# 1      2017-11-13T07:30:00.000Z
# 2      2017-11-12T19:05:24.000Z
# 3      2017-11-13T11:00:04.000Z
# 4      2017-11-12T18:01:41.000Z
# ...                         ...
# 40944  2018-05-18T13:00:04.000Z
# 40945  2018-05-18T01:00:06.000Z
# 40946  2018-05-18T17:34:22.000Z
# 40947  2018-05-17T17:00:04.000Z
# 40948  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 17 columns]

# %%
merged_df['trending_date'] = pd.to_datetime(merged_df['trending_date'], format='%y.%d.%m').dt.strftime('%Y-%m-%dT%H:%M:%S.000Z')
merged_df
# Out:
#           video_id             trending_date  \
# 0      2kyS6SvSYSE  2017-11-14T00:00:00.000Z
# 1      1ZAPwfrtAFY  2017-11-14T00:00:00.000Z
# 2      5qpjK5DgCt4  2017-11-14T00:00:00.000Z
# 3      puqaWrEC7tY  2017-11-14T00:00:00.000Z
# 4      d380meD0W0M  2017-11-14T00:00:00.000Z
# ...            ...                       ...
# 40944  BZt0qjTWNhw  2018-06-14T00:00:00.000Z
# 40945  1h7KV2sjUWY  2018-06-14T00:00:00.000Z
# 40946  D6Oy4LfoqsU  2018-06-14T00:00:00.000Z
# 40947  oV0zkMe1K8s  2018-06-14T00:00:00.000Z
# 40948  ooyjaVdt-jA  2018-06-14T00:00:00.000Z
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id    category_title  \
# 0                  CaseyNeistat           22    People & Blogs
# 1               LastWeekTonight           24     Entertainment
# 2                  Rudy Mancuso           23            Comedy
# 3         Good Mythical Morning           24     Entertainment
# 4                      nigahiga           24     Entertainment
# ...                         ...          ...               ...
# 40944             AaronsAnimals           15    Pets & Animals
# 40945                  zefrank1           22    People & Blogs
# 40946                Brad Mondo           24     Entertainment
# 40947  How It Should Have Ended            1  Film & Animation
# 40948              Call of Duty           20            Gaming
#
#                    publish_time  \
# 0      2017-11-13T17:13:01.000Z
# 1      2017-11-13T07:30:00.000Z
# 2      2017-11-12T19:05:24.000Z
# 3      2017-11-13T11:00:04.000Z
# 4      2017-11-12T18:01:41.000Z
# ...                         ...
# 40944  2018-05-18T13:00:04.000Z
# 40945  2018-05-18T01:00:06.000Z
# 40946  2018-05-18T17:34:22.000Z
# 40947  2018-05-17T17:00:04.000Z
# 40948  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 17 columns]

# %%
df_no_words = merged_df.drop(columns=['title', 'tags', 'thumbnail_link', 'description'])
df_no_words
# Out:
#           video_id             trending_date             channel_title  \
# 0      2kyS6SvSYSE  2017-11-14T00:00:00.000Z              CaseyNeistat
# 1      1ZAPwfrtAFY  2017-11-14T00:00:00.000Z           LastWeekTonight
# 2      5qpjK5DgCt4  2017-11-14T00:00:00.000Z              Rudy Mancuso
# 3      puqaWrEC7tY  2017-11-14T00:00:00.000Z     Good Mythical Morning
# 4      d380meD0W0M  2017-11-14T00:00:00.000Z                  nigahiga
# ...            ...                       ...                       ...
# 40944  BZt0qjTWNhw  2018-06-14T00:00:00.000Z             AaronsAnimals
# 40945  1h7KV2sjUWY  2018-06-14T00:00:00.000Z                  zefrank1
# 40946  D6Oy4LfoqsU  2018-06-14T00:00:00.000Z                Brad Mondo
# 40947  oV0zkMe1K8s  2018-06-14T00:00:00.000Z  How It Should Have Ended
# 40948  ooyjaVdt-jA  2018-06-14T00:00:00.000Z              Call of Duty
#
#        category_id    category_title              publish_time     views  \
# 0               22    People & Blogs  2017-11-13T17:13:01.000Z    748374
# 1               24     Entertainment  2017-11-13T07:30:00.000Z   2418783
# 2               23            Comedy  2017-11-12T19:05:24.000Z   3191434
# 3               24     Entertainment  2017-11-13T11:00:04.000Z    343168
# 4               24     Entertainment  2017-11-12T18:01:41.000Z   2095731
# ...            ...               ...                       ...       ...
# 40944           15    Pets & Animals  2018-05-18T13:00:04.000Z   1685609
# 40945           22    People & Blogs  2018-05-18T01:00:06.000Z   1064798
# 40946           24     Entertainment  2018-05-18T17:34:22.000Z   1066451
# 40947            1  Film & Animation  2018-05-17T17:00:04.000Z   5660813
# 40948           20            Gaming  2018-05-17T17:09:38.000Z  10306119
#
#         likes  dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0       57527      2966          15954              False             False
# 1       97185      6146          12703              False             False
# 2      146033      5339           8181              False             False
# 3       10172       666           2146              False             False
# 4      132235      1989          17518              False             False
# ...       ...       ...            ...                ...               ...
# 40944   38160      1385           2657              False             False
# 40945   60008       382           3936              False             False
# 40946   48068      1032           3992              False             False
# 40947  192957      2846          13088              False             False
# 40948  357079    212976         144795              False             False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 40944                   False
# 40945                   False
# 40946                   False
# 40947                   False
# 40948                   False
#
# [40949 rows x 13 columns]

# %%
count_unique = (merged_df.duplicated() == False).sum()
count_duplicates = (merged_df.duplicated() == True).sum()

print("Number of unique rows:", count_unique)
print("Number of duplicate rows:", count_duplicates)
# Out:
# Number of unique rows: 40901
# Number of duplicate rows: 48

# %%
duplicate_rows = merged_df[merged_df.duplicated(keep=False)]
duplicate_of_selected_rows = merged_df[merged_df.isin(duplicate_rows)].dropna()

# %%
duplicate_of_selected_rows
# Out:
#           video_id             trending_date  \
# 34750  QBL8IRJ5yHU  2018-05-15T00:00:00.000Z
# 34751  t4pRQ0jn23Q  2018-05-15T00:00:00.000Z
# 34752  j4KvrAUjn6c  2018-05-15T00:00:00.000Z
# 34753  MAjY8mCTXWk  2018-05-15T00:00:00.000Z
# 34754  xhs8tf1v__w  2018-05-15T00:00:00.000Z
# ...            ...                       ...
# 34944  iILJvqrAQ_w  2018-05-15T00:00:00.000Z
# 34945  zcEE8J2Bqa8  2018-05-15T00:00:00.000Z
# 34946  q1jzwV_s8_Y  2018-05-15T00:00:00.000Z
# 34947  mkz1zoo15zI  2018-05-15T00:00:00.000Z
# 34948  2PH7dK6SLC8  2018-05-15T00:00:00.000Z
#
#                                                    title     channel_title  \
# 34750  Why I'm So Scared (being myself and crying too...     grav3yardgirl
# 34751  YoungBoy Never Broke Again Goes Sneaker Shoppi...           Complex
# 34752         WE MADE OUR MOM CRY...HER DREAM CAME TRUE!  Lucas and Marcus
# 34753  周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's...   杰威爾音樂 JVR Music
# 34754  Terry Crews Answers the Web's Most Searched Qu...             WIRED
# ...                                                  ...               ...
# 34944                Charlie Puth - BOY [Official Audio]      Charlie Puth
# 34945                         The Goblin - JACK AND DEAN     Jack and Dean
# 34946                 Christina Aguilera - Twice (Audio)     CAguileraVEVO
# 34947  Richard Jefferson and Tracy McGrady have stron...              ESPN
# 34948                             John Mayer - New Light     johnmayerVEVO
#
#        category_id category_title              publish_time  \
# 34750         26.0  Howto & Style  2018-05-14T19:00:01.000Z
# 34751         24.0  Entertainment  2018-05-14T14:00:03.000Z
# 34752         24.0  Entertainment  2018-05-13T18:03:56.000Z
# 34753         10.0          Music  2018-05-14T15:59:47.000Z
# 34754         24.0  Entertainment  2018-05-14T16:00:29.000Z
# ...            ...            ...                       ...
# 34944         10.0          Music  2018-05-11T04:00:34.000Z
# 34945         23.0         Comedy  2018-05-11T18:27:01.000Z
# 34946         10.0          Music  2018-05-11T07:00:01.000Z
# 34947         17.0         Sports  2018-05-11T19:21:53.000Z
# 34948         10.0          Music  2018-05-10T17:00:01.000Z
#
#                                                     tags      views     likes  \
# 34750  beauty|"how to"|"makeup"|"howto"|"style"|"fash...  1469627.0  188652.0
# 34751  sneakerhead|"complex"|"complex originals"|"sne...  1199587.0   49709.0
# 34752  Lucas and Marcus|"Marcus and Lucas"|"Dobre"|"D...  3906727.0   77378.0
# 34753  周杰倫|"Jay"|"Chou"|"周董"|"周杰伦"|"周傑倫"|"杰威尔"|"周周"|"...   916128.0   40485.0
# 34754  autocomplete|"deadpool 2"|"google autocomplete...   343967.0   16988.0
# ...                                                  ...        ...       ...
# 34944  charlie puth|"boy"|"charlie"|"puth"|"atlantic"...  2124177.0   81085.0
# 34945  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...   165617.0   20572.0
# 34946  Christina Aguilera|"Pop"|"RCA Records Label"|"...  1869585.0   64523.0
# 34947  espn|"espn live"|"dwane casey"|"raptors"|"toro...   472999.0    3505.0
# 34948  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...  1201548.0   51670.0
#
#        dislikes  comment_count  \
# 34750    3124.0        33032.0
# 34751    2380.0         7261.0
# 34752   12160.0        15874.0
# 34753    1042.0         4746.0
# 34754     132.0         1308.0
# ...         ...            ...
# 34944    1321.0         4019.0
# 34945     140.0         1407.0
# 34946    1891.0         5903.0
# 34947     163.0         1511.0
# 34948     964.0         4264.0
#
#                                        thumbnail_link comments_disabled  \
# 34750  https://i.ytimg.com/vi/QBL8IRJ5yHU/default.jpg             False
# 34751  https://i.ytimg.com/vi/t4pRQ0jn23Q/default.jpg             False
# 34752  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg             False
# 34753  https://i.ytimg.com/vi/MAjY8mCTXWk/default.jpg             False
# 34754  https://i.ytimg.com/vi/xhs8tf1v__w/default.jpg             False
# ...                                               ...               ...
# 34944  https://i.ytimg.com/vi/iILJvqrAQ_w/default.jpg             False
# 34945  https://i.ytimg.com/vi/zcEE8J2Bqa8/default.jpg             False
# 34946  https://i.ytimg.com/vi/q1jzwV_s8_Y/default.jpg             False
# 34947  https://i.ytimg.com/vi/mkz1zoo15zI/default.jpg             False
# 34948  https://i.ytimg.com/vi/2PH7dK6SLC8/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 34750            False                  False
# 34751            False                  False
# 34752            False                  False
# 34753            False                  False
# 34754            False                  False
# ...                ...                    ...
# 34944            False                  False
# 34945            False                  False
# 34946            False                  False
# 34947            False                  False
# 34948            False                  False
#
#                                              description
# 34750  I will never be able to say Thank You enough.....
# 34751  YoungBoy Never Broke Again goes Sneaker Shoppi...
# 34752  BEST MOM EVER! WANT TO SEE US IN NYC & NJ?!BUY...
# 34753  詞：周杰倫、宋健彰（彈頭）  曲：周杰倫憂鬱型男的走心旋律  用英式搖滾宣洩情傷不愛我就拉倒...
# 34754  Terry Crews takes the WIRED Autocomplete Inter...
# ...                                                  ...
# 34944  Voicenotes Available Now: https://Atlantic.lnk...
# 34945  That? That's a goblin living under the stairs....
# 34946  Pre-order Christina Aguilera’s new album ‘Libe...
# 34947  Richard Jefferson and Tracy McGrady share thei...
# 34948  Spotify: http://radi.al/NewLightSpotifyApple: ...
#
# [94 rows x 17 columns]

# %%
df_unique = merged_df.drop_duplicates()

# %%
df_unique
# Out:
#           video_id             trending_date  \
# 0      2kyS6SvSYSE  2017-11-14T00:00:00.000Z
# 1      1ZAPwfrtAFY  2017-11-14T00:00:00.000Z
# 2      5qpjK5DgCt4  2017-11-14T00:00:00.000Z
# 3      puqaWrEC7tY  2017-11-14T00:00:00.000Z
# 4      d380meD0W0M  2017-11-14T00:00:00.000Z
# ...            ...                       ...
# 40944  BZt0qjTWNhw  2018-06-14T00:00:00.000Z
# 40945  1h7KV2sjUWY  2018-06-14T00:00:00.000Z
# 40946  D6Oy4LfoqsU  2018-06-14T00:00:00.000Z
# 40947  oV0zkMe1K8s  2018-06-14T00:00:00.000Z
# 40948  ooyjaVdt-jA  2018-06-14T00:00:00.000Z
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id    category_title  \
# 0                  CaseyNeistat           22    People & Blogs
# 1               LastWeekTonight           24     Entertainment
# 2                  Rudy Mancuso           23            Comedy
# 3         Good Mythical Morning           24     Entertainment
# 4                      nigahiga           24     Entertainment
# ...                         ...          ...               ...
# 40944             AaronsAnimals           15    Pets & Animals
# 40945                  zefrank1           22    People & Blogs
# 40946                Brad Mondo           24     Entertainment
# 40947  How It Should Have Ended            1  Film & Animation
# 40948              Call of Duty           20            Gaming
#
#                    publish_time  \
# 0      2017-11-13T17:13:01.000Z
# 1      2017-11-13T07:30:00.000Z
# 2      2017-11-12T19:05:24.000Z
# 3      2017-11-13T11:00:04.000Z
# 4      2017-11-12T18:01:41.000Z
# ...                         ...
# 40944  2018-05-18T13:00:04.000Z
# 40945  2018-05-18T01:00:06.000Z
# 40946  2018-05-18T17:34:22.000Z
# 40947  2018-05-17T17:00:04.000Z
# 40948  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40901 rows x 17 columns]

# %%
category_counts = df_unique['category_id'].value_counts()

# %%
category_counts
# Out:
# 24    9944
# 10    6467
# 26    4142
# 23    3453
# 22    3208
# 25    2485
# 28    2397
# 1     2343
# 17    2172
# 27    1655
# 15     920
# 20     816
# 19     401
# 2      384
# 29      57
# 43      57
# Name: category_id, dtype: int64

# %%
df_unique_v2 = df_unique.drop_duplicates(subset=['video_id', 'title', 'channel_title', 'publish_time'])

# %%
df_unique_v2
# Out:
#           video_id             trending_date  \
# 0      2kyS6SvSYSE  2017-11-14T00:00:00.000Z
# 1      1ZAPwfrtAFY  2017-11-14T00:00:00.000Z
# 2      5qpjK5DgCt4  2017-11-14T00:00:00.000Z
# 3      puqaWrEC7tY  2017-11-14T00:00:00.000Z
# 4      d380meD0W0M  2017-11-14T00:00:00.000Z
# ...            ...                       ...
# 40760  dS5Thrl-4Kc  2018-06-14T00:00:00.000Z
# 40761  JGm9Y_hFqNk  2018-06-14T00:00:00.000Z
# 40762  6h8QgZF5Qu4  2018-06-14T00:00:00.000Z
# 40764  mpnshdmtE2Y  2018-06-14T00:00:00.000Z
# 40766  yz7Xq3T0YPs  2018-06-14T00:00:00.000Z
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40760                      CRAYOLA MAKEUP | HIT OR MISS?
# 40761  First Take reacts: Kyrie Irving says contract ...
# 40762  Drop the Mic w/ Ashton Kutcher & Sean Diddy Combs
# 40764  Carla Makes BA Smashburgers | From the Test Ki...
# 40766  Katherine Langford on 13 Reasons Why, Australi...
#
#                               channel_title  category_id  category_title  \
# 0                              CaseyNeistat           22  People & Blogs
# 1                           LastWeekTonight           24   Entertainment
# 2                              Rudy Mancuso           23          Comedy
# 3                     Good Mythical Morning           24   Entertainment
# 4                                  nigahiga           24   Entertainment
# ...                                     ...          ...             ...
# 40760                             Laura Lee           26   Howto & Style
# 40761                                  ESPN           17          Sports
# 40762  The Late Late Show with James Corden           24   Entertainment
# 40764                           Bon Appétit           26   Howto & Style
# 40766                     Jimmy Kimmel Live           24   Entertainment
#
#                    publish_time  \
# 0      2017-11-13T17:13:01.000Z
# 1      2017-11-13T07:30:00.000Z
# 2      2017-11-12T19:05:24.000Z
# 3      2017-11-13T11:00:04.000Z
# 4      2017-11-12T18:01:41.000Z
# ...                         ...
# 40760  2018-06-12T18:55:26.000Z
# 40761  2018-06-13T15:06:08.000Z
# 40762  2018-06-13T05:27:27.000Z
# 40764  2018-06-12T16:03:58.000Z
# 40766  2018-06-13T09:00:06.000Z
#
#                                                     tags    views   likes  \
# 0                                        SHANtell martin   748374   57527
# 1      last week tonight trump presidency|"last week ...  2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# ...                                                  ...      ...     ...
# 40760  Laura88Lee|"crayola"|"crayon makeup"|"crayola ...   607422   26166
# 40761  espn|"espn live"|"boston celtics"|"kyrie irvin...   812832    7701
# 40762  The Late Late Show|"Late Late Show"|"James Cor...   864189   18811
# 40764  bon appetit|"burgers"|"cheeseburgers"|"how to ...   540149   14206
# 40766  jimmy|"kimmel"|"live"|"late"|"night"|"talk"|"s...   296295    8157
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40760       895           3517
# 40761       320           2505
# 40762       399           1074
# 40764       693           1211
# 40766       294            764
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40760  https://i.ytimg.com/vi/dS5Thrl-4Kc/default.jpg              False
# 40761  https://i.ytimg.com/vi/JGm9Y_hFqNk/default.jpg              False
# 40762  https://i.ytimg.com/vi/6h8QgZF5Qu4/default.jpg              False
# 40764  https://i.ytimg.com/vi/mpnshdmtE2Y/default.jpg              False
# 40766  https://i.ytimg.com/vi/yz7Xq3T0YPs/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40760             False                   False
# 40761             False                   False
# 40762             False                   False
# 40764             False                   False
# 40766             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40760  Hey Larlees, todays video is me testing Crayol...
# 40761  First Take's Stephen A. Smith and Max Kellerma...
# 40762  James Corden and Ashton Kutcher square off in ...
# 40764  Ground chuck is a great all-purpose, buy-it-an...
# 40766  Katherine talks about learning accents, growin...
#
# [6474 rows x 17 columns]

# %%
category_counts_v2 = df_unique_v2.groupby('category_id')['video_id'].count()
category_counts_v2
# Out:
# category_id
# 1      322
# 2       72
# 10     825
# 15     142
# 17     458
# 19      65
# 20     104
# 22     509
# 23     553
# 24    1645
# 25     511
# 26     602
# 27     257
# 28     390
# 29      15
# 43       4
# Name: video_id, dtype: int64

# %%
if callable(category_counts_v2):
    category_counts_v2 = category_counts_v2()

# %%
plt.figure(figsize=(10, 8)) 
plt.pie(category_counts_v2, labels=category_counts_v2.index, startangle=140)
plt.title('Distribution of Video IDs by Category')
plt.legend(category_counts_v2.index, loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
category_counts_df = pd.merge(category_counts_v2.reset_index(name='count'), id_to_title_df, left_on='category_id', right_on='id', how='left')
category_counts_df.drop(columns=['id'], inplace=True)
category_counts_df['percentage'] = round((category_counts_df['count'] / category_counts_df['count'].sum()) * 100, 2)
category_counts_df = category_counts_df.sort_values(by='count', ascending=False)
category_counts_df.reset_index(drop=True, inplace=True)

# %%
category_counts_df
# Out:
#     category_id  count         category_title  percentage
# 0            24   1606          Entertainment       25.52
# 1            10    794                  Music       12.62
# 2            26    591          Howto & Style        9.39
# 3            23    543                 Comedy        8.63
# 4            25    497        News & Politics        7.90
# 5            22    493         People & Blogs        7.83
# 6            17    449                 Sports        7.13
# 7            28    373   Science & Technology        5.93
# 8             1    317       Film & Animation        5.04
# 9            27    244              Education        3.88
# 10           15    135         Pets & Animals        2.15
# 11           20    103                 Gaming        1.64
# 12            2     70       Autos & Vehicles        1.11
# 13           19     60        Travel & Events        0.95
# 14           29     14  Nonprofits & Activism        0.22
# 15           43      4                  Shows        0.06
